# %%
import pandas as pd
import pyarrow as pa
import matplotlib.pyplot as plt
import seaborn as sns
import json
import plotly.express as px
import numpy as np
import os
import plotly.graph_objects as go
from datetime import datetime
import glob
import pyarrow

# %%
def getDayData(df): 
    # third column is one string, containing many different data items as dictionaries, separate those and flatten df
    df["parsed"] = df[2].apply(json.loads) 
    df2_flat = pd.json_normalize(df["parsed"])

    # Combine back with your original DataFrame 
    df2_flat = pd.concat([df, df2_flat], axis=1)
    df2_flat['extra.rentalBikes'] = df2_flat['extra.rentalBikes'].astype(float)
    df2_flat[0] = pd.to_datetime(df2_flat[0], format="ISO8601", errors="coerce", utc=True)

    df2_flat = df2_flat.rename(columns={0: "time"})

    # Drop unwanted columns all at once 
    drop_cols = [
        1, 2, 3, "link.uri", "thumbnail.uri", "extra.serviceType",
        "extra.type", "extraInfo", "apps", "sites", "houseNumber",
        "street", "openingHours", "open", "ovFiets", 
        "nearbyMeLocationId.type", "nearbyMeLocationId.value",
        "extra.locationCode", "name", "extra.fetchTime",
        "parsed", "infoImages", "postalCode"
    ]
    
    existing_drop_cols = [c for c in drop_cols if c in df2_flat.columns]
    if existing_drop_cols:
        df2_flat = df2_flat.drop(columns=existing_drop_cols)

    stations_to_keep = ["ASD", "DT", "GVC", "EHV", "UT", "MT", "RTD", "MDB", "NM", "ZL", "ES", "GN"]
    df_filtered = df2_flat[df2_flat["stationCode"].isin(stations_to_keep)]



    # Remove outliers (remove missing data)
    indices_to_drop = df_filtered[df_filtered['extra.rentalBikes'] == df_filtered["extra.rentalBikes"].max()].index ## change
    df_filtered = df_filtered.drop(indices_to_drop)

    ## reset index
    new_df = df_filtered.reset_index(drop=True)

    return new_df

# %%
# folder_1 = "ovfiets_november"
# existing_table_2023 = pd.DataFrame()
in_folder = 'ovfiets_2023'
out_folder = "ovfiets_parquet"
# os.makedirs(out_folder, exist_ok=True)

start_from = "OVFiets_2023-04-01.csv.xz"  # change this to the file you want to start from
end_at = "OVFiets_2023-07-01.csv.xz"


# Get sorted list of files
all_files = sorted(os.listdir(in_folder))

# If a start file is set, skip everything before it
if start_from in all_files:
    start_index = all_files.index(start_from)
    end_index = all_files.index(end_at)
    files_to_process = all_files[start_index:end_index]


# Get 2024 data
for name in files_to_process:    
    path = os.path.join(in_folder, name)
    open_df = pd.read_csv(path, header = None)

    print (f'Opened file -> {name}')

    reworked_df = getDayData(open_df)
    # print(reworked_df)

    # print (f'Data successfully reformated {name}')

    # create a useful output filename, e.g. base + .parquet
    base = os.path.basename(name).replace(".csv.xz", "")
    out_path = os.path.join(out_folder, f"{base}.parquet")

    # save as parquet (use 'pyarrow' or 'fastparquet' backend if available)
    reworked_df.to_parquet(out_path, index=False, engine='pyarrow')
    print("Saved:", out_path)

    # print (f'Data done and saved => {name}')
# Out:
# Opened file -> OVFiets_2023-04-01.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-04-01.parquet
# Opened file -> OVFiets_2023-04-02.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-04-02.parquet
# Opened file -> OVFiets_2023-04-03.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-04-03.parquet
# Opened file -> OVFiets_2023-04-04.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-04-04.parquet
# Opened file -> OVFiets_2023-04-05.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-04-05.parquet
# Opened file -> OVFiets_2023-04-06.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-04-06.parquet
# Opened file -> OVFiets_2023-04-07.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-04-07.parquet
# Opened file -> OVFiets_2023-04-08.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-04-08.parquet
# Opened file -> OVFiets_2023-04-09.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-04-09.parquet
# Opened file -> OVFiets_2023-04-10.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-04-10.parquet
# Opened file -> OVFiets_2023-04-11.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-04-11.parquet
# Opened file -> OVFiets_2023-04-12.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-04-12.parquet
# Opened file -> OVFiets_2023-04-13.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-04-13.parquet
# Opened file -> OVFiets_2023-04-14.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-04-14.parquet
# Opened file -> OVFiets_2023-04-15.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-04-15.parquet
# Opened file -> OVFiets_2023-04-16.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-04-16.parquet
# Opened file -> OVFiets_2023-04-17.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-04-17.parquet
# Opened file -> OVFiets_2023-04-18.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-04-18.parquet
# Opened file -> OVFiets_2023-04-19.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-04-19.parquet
# Opened file -> OVFiets_2023-04-20.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-04-20.parquet
# Opened file -> OVFiets_2023-04-21.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-04-21.parquet
# Opened file -> OVFiets_2023-04-22.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-04-22.parquet
# Opened file -> OVFiets_2023-04-23.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-04-23.parquet
# Opened file -> OVFiets_2023-04-24.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-04-24.parquet
# Opened file -> OVFiets_2023-04-25.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-04-25.parquet
# Opened file -> OVFiets_2023-04-26.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-04-26.parquet
# Opened file -> OVFiets_2023-04-27.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-04-27.parquet
# Opened file -> OVFiets_2023-04-28.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-04-28.parquet
# Opened file -> OVFiets_2023-04-29.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-04-29.parquet
# Opened file -> OVFiets_2023-04-30.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-04-30.parquet
# Opened file -> OVFiets_2023-05-01.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-05-01.parquet
# Opened file -> OVFiets_2023-05-02.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-05-02.parquet
# Opened file -> OVFiets_2023-05-03.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-05-03.parquet
# Opened file -> OVFiets_2023-05-04.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-05-04.parquet
# Opened file -> OVFiets_2023-05-05.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-05-05.parquet
# Opened file -> OVFiets_2023-05-06.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-05-06.parquet
# Opened file -> OVFiets_2023-05-07.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-05-07.parquet
# Opened file -> OVFiets_2023-05-08.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-05-08.parquet
# Opened file -> OVFiets_2023-05-09.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-05-09.parquet
# Opened file -> OVFiets_2023-05-11.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-05-11.parquet
# Opened file -> OVFiets_2023-05-12.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-05-12.parquet
# Opened file -> OVFiets_2023-05-13.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-05-13.parquet
# Opened file -> OVFiets_2023-05-14.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-05-14.parquet
# Opened file -> OVFiets_2023-05-15.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-05-15.parquet
# Opened file -> OVFiets_2023-05-16.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-05-16.parquet
# Opened file -> OVFiets_2023-05-17.csv.xz
# Saved: ovfiets_parquet\OVFiets_2023-05-17.parquet
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 24
#      22 for name in files_to_process:
#      23     path = os.path.join(in_folder, name)
# ---> 24     open_df = pd.read_csv(path, header = None)
#      26     print (f'Opened file -> {name}')
#      28     reworked_df = getDayData(open_df)
#
# File c:\Users\annav\anaconda3\envs\TIL6022\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\annav\anaconda3\envs\TIL6022\Lib\site-packages\pandas\io\parsers\readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File c:\Users\annav\anaconda3\envs\TIL6022\Lib\site-packages\pandas\io\parsers\readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File c:\Users\annav\anaconda3\envs\TIL6022\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File pandas/_libs/parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File pandas/_libs/parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File pandas/_libs/parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File pandas/_libs/parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File pandas/_libs/parsers.pyx:2053, in pandas._libs.parsers.raise_parser_error()
#
# File c:\Users\annav\anaconda3\envs\TIL6022\Lib\lzma.py:212, in LZMAFile.read1(self, size)
#     210 if size < 0:
#     211     size = io.DEFAULT_BUFFER_SIZE
# --> 212 return self._buffer.read1(size)
#
# File c:\Users\annav\anaconda3\envs\TIL6022\Lib\_compression.py:68, in DecompressReader.readinto(self, b)
#      66 def readinto(self, b):
#      67     with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68         data = self.read(len(byte_view))
#      69         byte_view[:len(data)] = data
#      70     return len(data)
#
# File c:\Users\annav\anaconda3\envs\TIL6022\Lib\_compression.py:103, in DecompressReader.read(self, size)
#     101     else:
#     102         rawblock = b""
# --> 103     data = self._decompressor.decompress(rawblock, size)
#     104 if data:
#     105     break
#
# KeyboardInterrupt:
